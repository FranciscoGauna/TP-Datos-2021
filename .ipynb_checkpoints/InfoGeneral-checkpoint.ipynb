# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import squarify
df_train_labels_original = pd.read_csv('train_labels.csv',low_memory=False)
df_train_values_original = pd.read_csv('train_values.csv',low_memory=False, dtype= {
'geo_level_1_id':'uint8', 'geo_level_2_id':'uint16', 'geo_level_3_id':'uint16', 'count_floors_pre_eq':'uint8','age':'uint16', 'area_percentage':'uint16', 'height_percentage':'uint16', 
'land_surface_condition':'category', 'foundation_type':'category', 'roof_type':'category', 'ground_floor_type':'category', 'other_floor_type':'category', 'position':'category','plan_configuration':'category', 
'has_superstructure_adobe_mud':'bool', 'has_superstructure_mud_mortar_stone':'bool','has_superstructure_stone_flag':'bool', 'has_superstructure_cement_mortar_stone':'bool', 'has_superstructure_mud_mortar_brick':'bool', 'has_superstructure_cement_mortar_brick':'bool', 'has_superstructure_timber':'bool', 'has_superstructure_bamboo':'bool', 'has_superstructure_rc_non_engineered':'bool', 'has_superstructure_rc_engineered':'bool', 'has_superstructure_other':'bool', 
'legal_ownership_status':'category', 'count_families':'uint16', 
'has_secondary_use':'bool', 'has_secondary_use_agriculture':'bool', 'has_secondary_use_hotel':'bool', 'has_secondary_use_rental':'bool', 'has_secondary_use_institution':'bool', 'has_secondary_use_school':'bool', 'has_secondary_use_industry':'bool', 'has_secondary_use_health_post':'bool', 'has_secondary_use_gov_office':'bool', 'has_secondary_use_use_police':'bool', 'has_secondary_use_other':'bool',})

# %%
df_train_labels_original.head(10)
# Out:
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             3
# 5       333020             2
# 6       728451             3
# 7       475515             1
# 8       441126             2
# 9       989500             1

# %%
df_train_labels_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 2 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   building_id   260601 non-null  int64
#  1   damage_grade  260601 non-null  int64
# dtypes: int64(2)
# memory usage: 4.0 MB

# %%
df_train_values_original.head(10)
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
# 5       333020               8             558            6089
# 6       728451               9             475           12066
# 7       475515              20             323           12236
# 8       441126               0             757            7219
# 9       989500              26             886             994
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# ...

# %%
df_train_values_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  uint8
#  2   geo_level_2_id                          260601 non-null  uint16
#  3   geo_level_3_id                          260601 non-null  uint16
#  4   count_floors_pre_eq                     260601 non-null  uint8
#  5   age                                     260601 non-null  uint16
#  6   area_percentage                         260601 non-null  uint16
#  7   height_percentage                       260601 non-null  uint16
#  8   land_surface_condition                  260601 non-null  category
#  9   foundation_type                         260601 non-null  category
# ...

# %%
df_train_values_original['land_surface_condition'].value_counts()
# Out:
# t    216757
# n     35528
# o      8316
# Name: land_surface_condition, dtype: int64

# %%
df_train_values_original['foundation_type'].value_counts()
# Out:
# r    219196
# w     15118
# u     14260
# i     10579
# h      1448
# Name: foundation_type, dtype: int64

# %%
df_train_values_original['roof_type'].value_counts()
# Out:
# n    182842
# q     61576
# x     16183
# Name: roof_type, dtype: int64

# %%
df_train_values_original['ground_floor_type'].value_counts()
# Out:
# f    209619
# x     24877
# v     24593
# z      1004
# m       508
# Name: ground_floor_type, dtype: int64

# %%
df_train_values_original['other_floor_type'].value_counts()
# Out:
# q    165282
# x     43448
# j     39843
# s     12028
# Name: other_floor_type, dtype: int64

# %%
df_train_values_original['position'].value_counts()
# Out:
# s    202090
# t     42896
# j     13282
# o      2333
# Name: position, dtype: int64

# %%
df_train_values_original['plan_configuration'].value_counts()
# Out:
# d    250072
# q      5692
# u      3649
# s       346
# c       325
# a       252
# o       159
# m        46
# n        38
# f        22
# Name: plan_configuration, dtype: int64

# %%
df_train_values_original['legal_ownership_status'].value_counts()
# Out:
# v    250939
# a      5512
# w      2677
# r      1473
# Name: legal_ownership_status, dtype: int64

# %% [markdown]
# ------

# %%
df_train_values_original['count_floors_pre_eq'].value_counts()
# Out:
# 2    156623
# 3     55617
# 1     40441
# 4      5424
# 5      2246
# 6       209
# 7        39
# 9         1
# 8         1
# Name: count_floors_pre_eq, dtype: int64

# %%
df_train_values_original[['count_floors_pre_eq','building_id']].head(10)
# Out:
#    count_floors_pre_eq  building_id
# 0                    2       802906
# 1                    2        28830
# 2                    2        94947
# 3                    2       590882
# 4                    3       201944
# 5                    2       333020
# 6                    2       728451
# 7                    2       475515
# 8                    2       441126
# 9                    1       989500

# %%
df_train_labels_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 2 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   building_id   260601 non-null  int64
#  1   damage_grade  260601 non-null  int64
# dtypes: int64(2)
# memory usage: 4.0 MB

# %% [markdown]
# # Cantidad de edificios dañados segun tipo de daño y cantidad de pisos (excluidos los de 6+ pisos porque no representan el 1%)

# %%
edificios_x_piso_y_damage = df_train_values_original[df_train_values_original['count_floors_pre_eq'] < 6].merge(df_train_labels_original, on='building_id')[['building_id', 'count_floors_pre_eq', 'damage_grade']].groupby(['count_floors_pre_eq', 'damage_grade']).agg({'building_id': 'count'}).reset_index()
edificios_x_piso_y_damage.columns = ["Pisos", "Daño", "Cantidad"]
edificios_x_piso_y_damage
# Out:
#     Pisos  Daño  Cantidad
# 0       1     1      8969
# 1       1     2     20798
# 2       1     3     10674
# 3       2     1     12593
# 4       2     2     93968
# 5       2     3     50062
# 6       3     1      2537
# 7       3     2     28479
# 8       3     3     24601
# 9       4     1       707
# 10      4     2      3374
# 11      4     3      1343
# 12      5     1       254
# 13      5     2      1481
# 14      5     3       511

# %%
fig,ax=plt.subplots(figsize=(20,15))

plt.grid(True)
g = sns.barplot(ax=ax,data=edificios_x_piso_y_damage,x='Pisos',y='Cantidad',palette=['Gold', 'Orange', 'Tomato'],alpha=1,hue='Daño')
g.set_title('Cantidad de edificios dañados segun tipo de daño y cantidad de pisos \n',size=35)
g.set_xlabel('Cantidad de pisos',size=25)
g.set_ylabel('Cantidad de edificios dañados',size=25)
fig.get_axes()[0].set_yscale('log')
g.legend(title='Grado de daño')

# %% [markdown]
# # Analisis sobre datos de area_percentage y height_percentage

# %%
df_merged_area_height = df_train_values_original[['building_id', 'area_percentage', 'height_percentage']].merge(df_train_labels_original, on='building_id')
df_merged_area_height.head(10)
# Out:
#    building_id  area_percentage  height_percentage  damage_grade
# 0       802906                6                  5             3
# 1        28830                8                  7             2
# 2        94947                5                  5             3
# 3       590882                6                  5             2
# 4       201944                8                  9             3
# 5       333020                9                  5             2
# 6       728451                3                  4             3
# 7       475515                8                  6             1
# 8       441126                8                  6             2
# 9       989500               13                  4             1

# %%
df_merged_area_height['area_ratio'] = df_merged_area_height['area_percentage'] / df_merged_area_height['height_percentage']
df_damage_percentage_by_area_ratio = df_merged_area_height[['area_ratio', 'damage_grade' ]].groupby(['area_ratio']).agg({'damage_grade': 'mean'}).reset_index()

# %% [markdown]
# ## Relacion entre la superficie ocupada y el grado de daño recibido

# %%
df_damage_percentage_by_area_percentage = df_merged_area_height[['area_percentage', 'damage_grade']].groupby(['area_percentage']).agg({'damage_grade': ['mean','count']}).reset_index()
df_damage_percentage_by_area_percentage.columns = ["Superficie normalizada", "Promedio de grado de daño", "count"]
df_damage_percentage_by_area_percentage_filtered = df_damage_percentage_by_area_percentage[df_damage_percentage_by_area_percentage['count'] > (df_damage_percentage_by_area_percentage['count'].max()*0.1)]
df_damage_percentage_by_area_percentage_filtered
# Out:
#     Superficie normalizada  Promedio de grado de daño  count
# 2                        3                   2.280139  11837
# 3                        4                   2.261281  19236
# 4                        5                   2.306503  32724
# 5                        6                   2.297908  42013
# 6                        7                   2.278325  36752
# 7                        8                   2.261452  28445
# 8                        9                   2.234695  22199
# 9                       10                   2.209889  15613
# 10                      11                   2.184655  13907
# 11                      12                   2.145627   7581
# 12                      13                   2.148753   5815

# %%
# plot
fig,ax=plt.subplots(figsize=(15,10))
g = sns.regplot(x=df_damage_percentage_by_area_percentage_filtered["Superficie normalizada"], y=df_damage_percentage_by_area_percentage_filtered["Promedio de grado de daño"], line_kws={"color":"r","alpha":0.7,"lw":5}, scatter_kws={'s':100})
g.set_title('Relacion entre la superficie ocupada y el grado de daño recibido\n',size=35)
g.set_xlabel('Superficie normalizada',size=25)
g.set_ylabel('Promedio de grado de daño',size=25)
plt.show()

# %% [markdown]
# ## Relacion entre la altura de la edificacion y el grado de daño recibido

# %%
df_damage_percentage_by_height_percentage = df_merged_area_height[['height_percentage', 'damage_grade']].groupby(['height_percentage']).agg({'damage_grade': ['mean','count']}).reset_index()
df_damage_percentage_by_height_percentage.columns = ["height_percentage", "damage_percentage", "count"]
df_damage_percentage_by_height_percentage_filtered = df_damage_percentage_by_height_percentage[df_damage_percentage_by_height_percentage['count'] > (df_damage_percentage_by_height_percentage['count'].max()*0.1)]
df_damage_percentage_by_height_percentage_filtered
# Out:
#    height_percentage  damage_percentage  count
# 0                  2           2.156905   9305
# 1                  3           2.002966  25957
# 2                  4           2.221698  37763
# 3                  5           2.270019  78513
# 4                  6           2.303354  46477
# 5                  7           2.319188  35465
# 6                  8           2.336426  13902

# %%
# plot
fig,ax=plt.subplots(figsize=(15,10))
g = sns.regplot(x=df_damage_percentage_by_height_percentage_filtered["height_percentage"], y=df_damage_percentage_by_height_percentage_filtered["damage_percentage"], line_kws={"color":"r","alpha":0.7,"lw":5}, scatter_kws={'s':100})
g.set_title('Relacion entre la altura de la edificacion y el grado de daño recibido\n',size=35)
g.set_xlabel('Altura normalizada',size=25)
g.set_ylabel('Promedio de grado de daño',size=25)
plt.show()

# %% [markdown]
# ## """""Relacion entre el ratio (superficie / altura) de la edificacion y el grado de daño recibido"""""

# %%
df_damage_percentage_by_area_height_ratio = df_merged_area_height[['area_ratio', 'damage_grade']].groupby(['area_ratio']).agg({'damage_grade': ['mean','count']}).reset_index()
df_damage_percentage_by_area_height_ratio.columns = ["area_ratio", "damage_percentage", "count"]
df_damage_percentage_by_area_height_ratio_filtered = df_damage_percentage_by_area_height_ratio[df_damage_percentage_by_area_height_ratio['count'] > (df_damage_percentage_by_area_height_ratio['count'].max()*0.1)]
df_damage_percentage_by_area_height_ratio_filtered
# Out:
#      area_ratio  damage_percentage  count
# 62     0.600000           2.340909   3520
# 70     0.666667           2.290468   3546
# 75     0.714286           2.434100   3566
# 81     0.750000           2.304695   4260
# 86     0.800000           2.297634   6256
# 89     0.833333           2.357550   5258
# 92     0.857143           2.400898   5570
# 107    1.000000           2.297034  33215
# 121    1.142857           2.316024   4487
# 124    1.166667           2.338642   7347
# 128    1.200000           2.280208  14450
# 134    1.250000           2.264686   7337
# 138    1.285714           2.311216   3602
# 142    1.333333           2.229802   8751
# 148    1.400000           2.260064  12147
# 156    1.500000           2.249850  13320
# 165    1.600000           2.266949   8983
# 171    1.666667           2.181543   6610
# 179    1.750000           2.226976   5983
# 182    1.800000           2.229883   6947
# 199    2.000000           2.182623  15814
# ...

# %%
fig,ax=plt.subplots(figsize=(15,10))
g = sns.regplot(x=df_damage_percentage_by_area_height_ratio_filtered["area_ratio"], y=df_damage_percentage_by_area_height_ratio_filtered["damage_percentage"], line_kws={"color":"r","alpha":0.7,"lw":5}, scatter_kws={'s':100})
g.set_title('Relacion entre el ratio (superficie / altura) de la edificacion\n y el grado de daño recibido\n',size=35)
g.set_xlabel('Ratio (superficie / altura)',size=25)
g.set_ylabel('Promedio de grado de daño',size=25)
plt.show()

# %%
df_merged_position = df_train_values_original[['building_id', 'position']].merge(df_train_labels_original, on='building_id')
df_merged_position.head(10)
# Out:
#    building_id position  damage_grade
# 0       802906        t             3
# 1        28830        s             2
# 2        94947        t             3
# 3       590882        s             2
# 4       201944        s             3
# 5       333020        s             2
# 6       728451        s             3
# 7       475515        s             1
# 8       441126        s             2
# 9       989500        s             1

# %%
df_merged_position_damage = df_merged_position.groupby(['position','damage_grade']).agg({'building_id':['count']}).reset_index()
df_merged_position_damage.columns = ['position', 'damage_grade', 'building_count']
df_merged_position_damage
# Out:
#    position  damage_grade  building_count
# 0         j             1            1675
# 1         j             2            7899
# 2         j             3            3708
# 3         o             1             120
# 4         o             2            1609
# 5         o             3             604
# 6         s             1           19867
# 7         s             2          116051
# 8         s             3           66172
# 9         t             1            3462
# 10        t             2           22700
# 11        t             3           16734

# %%
df_merged_position_damage['total_building_by_pos'] = df_merged_position_damage[['position','building_count']].groupby(['position']).transform('sum')
df_merged_position_damage['proportion'] = df_merged_position_damage['building_count'] / df_merged_position_damage['total_building_by_pos']
df_merged_position_damage
# Out:
#    position  damage_grade  building_count  total_building_by_pos  proportion
# 0         j             1            1675                  13282    0.126111
# 1         j             2            7899                  13282    0.594715
# 2         j             3            3708                  13282    0.279175
# 3         o             1             120                   2333    0.051436
# 4         o             2            1609                   2333    0.689670
# 5         o             3             604                   2333    0.258894
# 6         s             1           19867                 202090    0.098308
# 7         s             2          116051                 202090    0.574254
# 8         s             3           66172                 202090    0.327438
# 9         t             1            3462                  42896    0.080707
# 10        t             2           22700                  42896    0.529187
# ...

# %%
damage_1 = df_merged_position_damage[df_merged_position_damage['damage_grade'] == 1]
damage_2 = df_merged_position_damage[df_merged_position_damage['damage_grade'] == 2]
damage_3 = df_merged_position_damage[df_merged_position_damage['damage_grade'] == 3]
damage_12 = df_merged_position_damage[df_merged_position_damage['damage_grade'] < 3][['position', 'proportion']].groupby(['position']).agg({'proportion':'sum'})

# %%
# Seteos grales del grafico
fig,ax=plt.subplots(figsize=(15,10))
barWidth = 0.25
 
# Seteo de lista de datos
g_damage_1 = damage_1['proportion']
g_damage_2 = damage_2['proportion']
g_damage_3 = damage_3['proportion']
g_damage_12  = damage_12['proportion']
 
# Seteo posiciones de barras
r1 = np.arange(len(damage_1))
r2 = [x + barWidth for x in r1]
 
# Genero Grafico
plt.bar(r1, g_damage_1, color='Gold', width=barWidth, edgecolor='white', label='Grado de Daño 1')
plt.bar(r1, g_damage_2, bottom=g_damage_1, color='Orange', width=barWidth, edgecolor='white', label='Grado de Daño 2')
plt.bar(r1, g_damage_3, bottom=g_damage_12, color='Tomato', width=barWidth, edgecolor='white', label='Grado de Daño 3')
 
# Seteo descripcion de ejes
plt.xlabel('Orientacion', fontweight='bold',size=25)
plt.ylabel('Proporcion segun grado de daño', fontweight='bold',size=25)
plt.xticks([r + barWidth/2 for r in range(5)], df_merged_position_damage["position"].unique())
 
# Muestro grafico
plt.title('Proporcion del grado de daño segun la orientacion de los edificios.\n',size=35)
plt.legend()

plt.tight_layout()
####plt.savefig("pngs/region-aprob-stage.png")

####plt.tight_layout()
####plt.savefig("pngs/relacion-lost-won-por-region-segun-aprobacion-precio.png")

plt.show()

# %% [markdown]
# Comentario: La proporcion segun el grado de daño no varia para los edificios con distintas orientaciones. Era de esperarse que la orientacion no influya en la distribucion de daño.

# %%
df_original = pd.read_csv('train_values.csv',low_memory=False)
#df_prueba_union_superestructure = df_original[['building_id', 'has_superstructure_adobe_mud', 'has_superstructure_mud_mortar_stone', 'has_superstructure_stone_flag', 'has_superstructure_cement_mortar_stone', 'has_superstructure_mud_mortar_brick', 'has_superstructure_cement_mortar_brick', 'has_superstructure_timber', 'has_superstructure_bamboo', 'has_superstructure_rc_non_engineered', 'has_superstructure_rc_engineered', 'has_superstructure_other']]
df_original['superstructure_type'] = df_original['has_superstructure_adobe_mud'] + 2*df_original['has_superstructure_mud_mortar_stone'] + 4*df_original['has_superstructure_stone_flag'] + 8*df_original['has_superstructure_cement_mortar_stone'] + 16*df_original['has_superstructure_mud_mortar_brick'] + 32*df_original['has_superstructure_cement_mortar_brick'] + 64*df_original['has_superstructure_timber'] + 128*df_original['has_superstructure_bamboo'] + 256*df_original['has_superstructure_rc_non_engineered'] + 512*df_original['has_superstructure_rc_engineered'] + 1024*df_original['has_superstructure_other']

# %%
#df_original2 = df_original[['building_id', 'has_superstructure_adobe_mud', 'has_superstructure_mud_mortar_stone', 'has_superstructure_stone_flag', 'has_superstructure_cement_mortar_stone', 'has_superstructure_mud_mortar_brick', 'has_superstructure_cement_mortar_brick', 'has_superstructure_timber', 'has_superstructure_bamboo', 'has_superstructure_rc_non_engineered', 'has_superstructure_rc_engineered', 'has_superstructure_other']] 
df_superstructure_type_count = df_original[['building_id', 'superstructure_type']].groupby(['superstructure_type']).agg({'building_id': 'count'}).reset_index().rename(columns={"building_id":"count"})
df_superstructure_type_count.nlargest(10, 'count')
# Out:
#      superstructure_type   count
# 1                      2  137134
# 60                    66   28861
# 30                    32   10106
# 135                  194    9980
# 0                      1    7229
# 15                    16    6144
# 58                    64    5145
# 186                  256    4167
# 16                    17    3925
# 133                  192    3558

# %%
df_original['superstructure_type'].value_counts()
# Out:
# 2       137134
# 66       28861
# 32       10106
# 194       9980
# 1         7229
#          ...
# 1352         1
# 1046         1
# 278          1
# 1480         1
# 383          1
# Name: superstructure_type, Length: 505, dtype: int64

# %%
df_train_values_original['superstructure_type']  = df_train_values_original['superstructure_type'] = df_train_values_original['has_superstructure_adobe_mud'] + 2*df_train_values_original['has_superstructure_mud_mortar_stone'] + 4*df_train_values_original['has_superstructure_stone_flag'] + 8*df_train_values_original['has_superstructure_cement_mortar_stone'] + 16*df_train_values_original['has_superstructure_mud_mortar_brick'] + 32*df_train_values_original['has_superstructure_cement_mortar_brick'] + 64*df_train_values_original['has_superstructure_timber'] + 128*df_train_values_original['has_superstructure_bamboo'] + 256*df_train_values_original['has_superstructure_rc_non_engineered'] + 512*df_train_values_original['has_superstructure_rc_engineered'] + 1024*df_train_values_original['has_superstructure_other']
df_superstructure_type_count = df_train_values_original[['building_id', 'superstructure_type']].groupby(['superstructure_type']).agg({'building_id': 'count'}).reset_index().rename(columns={"building_id":"count"})
df_superstructure_type_count.nlargest(10, 'count')
# Out:
#      superstructure_type   count
# 1                      2  137134
# 60                    66   28861
# 30                    32   10106
# 135                  194    9980
# 0                      1    7229
# 15                    16    6144
# 58                    64    5145
# 186                  256    4167
# 16                    17    3925
# 133                  192    3558

# %%
df_merged = df_train_values_original.merge(df_train_labels_original, on='building_id')

# %%
df_merged['superstructure_type'] = df_merged['has_superstructure_adobe_mud'] + 2*df_merged['has_superstructure_mud_mortar_stone'] + 4*df_merged['has_superstructure_stone_flag'] + 8*df_merged['has_superstructure_cement_mortar_stone'] + 16*df_merged['has_superstructure_mud_mortar_brick'] + 32*df_merged['has_superstructure_cement_mortar_brick'] + 64*df_merged['has_superstructure_timber'] + 128*df_merged['has_superstructure_bamboo'] + 256*df_merged['has_superstructure_rc_non_engineered'] + 512*df_merged['has_superstructure_rc_engineered'] + 1024*df_merged['has_superstructure_other']
df_merged_superstructure_damage = df_merged[['building_id', 'superstructure_type', 'damage_grade']].groupby(['superstructure_type']).agg({'building_id': 'count', 'damage_grade': 'mean'}).reset_index().rename(columns={"building_id":"count"})
df_merged_superstructure_damage_filtered = df_merged_superstructure_damage[df_merged_superstructure_damage['count'] > df_merged_superstructure_damage['count'].max()*0.03]
g_df_merged_superstructure_damage_filtered = df_merged_superstructure_damage_filtered.nsmallest(5, 'damage_grade').sort_values("damage_grade",ascending=True)
g_df_merged_superstructure_damage_filtered
# Out:
#      superstructure_type  count  damage_grade
# 186                  256   4167      1.471322
# 30                    32  10106      1.629329
# 58                    64   5145      1.652478
# 135                  194   9980      2.188778
# 15                    16   6144      2.238118

# %%
fig,ax=plt.subplots(figsize=(10,5))
sns.barplot(data=g_df_merged_superstructure_damage_filtered,x='superstructure_type',y='damage_grade', palette="RdYlBu", order=g_df_merged_superstructure_damage_filtered['superstructure_type'])
plt.grid(True)
plt.xlabel('Tipo de estructura',size=15)
plt.ylabel('Promedio de daño')
plt.title('TOP 5 estructuras con menor daño\n',size=22)
ax.set_xticklabels(['rc_non_engineered', 'cement_mortar_brick', 'timber', 'mud_mortar_stone +\ntimber +\nbamboo', 'mud_mortar_brick'], fontsize=10)
plt.tight_layout()

# %%
g2_df_merged_superstructure_damage_filtered = df_merged_superstructure_damage_filtered.nlargest(5, 'count').sort_values("count",ascending=False)
g2_df_merged_superstructure_damage_filtered
# Out:
#      superstructure_type   count  damage_grade
# 1                      2  137134      2.374896
# 60                    66   28861      2.257787
# 30                    32   10106      1.629329
# 135                  194    9980      2.188778
# 0                      1    7229      2.361737

# %%
fig,ax=plt.subplots(figsize=(10,5))
sns.barplot(data=g2_df_merged_superstructure_damage_filtered,x='superstructure_type',y='damage_grade', palette="RdYlBu", order=g2_df_merged_superstructure_damage_filtered['superstructure_type'])
plt.grid(True)
plt.xlabel('Tipo de estructura',size=15)
plt.ylabel('Promedio de daño')
plt.title('Promedio de daño de las 5 estructuras mas construidas\n',size=22)
ax.set_xticklabels(['1. mud_mortar_stone', '2. mud_mortar_stone +\ntimber', '3. cement_mortar_brick', '4. mud_mortar_stone +\ntimber +\nbamboo', '5. adobe_mud'], fontsize=10)
plt.tight_layout()

# %%
df_col_correlation = df_train_values_original[['count_floors_pre_eq', 'age', 'area_percentage', 'height_percentage', 'count_families',\
                                               'has_superstructure_adobe_mud', 'has_superstructure_mud_mortar_stone', 'has_superstructure_stone_flag', 'has_superstructure_cement_mortar_stone', 'has_superstructure_mud_mortar_brick', 'has_superstructure_cement_mortar_brick', 'has_superstructure_timber', 'has_superstructure_bamboo', 'has_superstructure_rc_non_engineered', 'has_superstructure_rc_engineered', 'has_superstructure_other',\
                                              'has_secondary_use', 'has_secondary_use_agriculture', 'has_secondary_use_hotel', 'has_secondary_use_rental', 'has_secondary_use_institution', 'has_secondary_use_school', 'has_secondary_use_industry', 'has_secondary_use_health_post', 'has_secondary_use_gov_office', 'has_secondary_use_use_police', 'has_secondary_use_other']]

# %%
#df_train_values_original.info()

# %%
g_df_col_correlation = df_col_correlation.corr().abs().round(2)
plt.figure(figsize=(15, 15))
ax = sns.heatmap(g_df_col_correlation, cmap="Blues");
plt.title("Correlación entre columnas", size=30)
ax.tick_params(labelsize=15)
ax.tick_params(axis='x', rotation=90)
ax.tick_params(axis='y', rotation=0)

# %%
#df_ground_floor_type = df_train_values_original[['ground_floor_type', 'building_id']].groupby(['ground_floor_type']).count()
#df_op = df.groupby('Opportunity_ID').agg({'Territory': 'first'}).reset_index()
#territories = df_op['Territory'].value_counts()
#territories = territories.drop('None')
#data = territories.head(3)
df_ground_floor_type = df_train_values_original['ground_floor_type'].value_counts()

visu = squarify.plot(df_ground_floor_type, label=df_ground_floor_type.index, alpha=.5, color=['#07efeb', '#1ec4dc', '#369acd', '#4d6fbe', '#6644af'])
visu.set_title('Tipos de construcción usados en la planta baja\n')
# Out:
# Text(0.5, 1.0, 'Tipos de construcción usados en la planta baja\n')

# %%
df_other_floor_type = df_train_values_original['other_floor_type'].value_counts()

visu = squarify.plot(df_other_floor_type, label=df_other_floor_type.index, alpha=.5, color=['#07efeb', '#1ec4dc', '#369acd', '#4d6fbe'])
visu.set_title('Tipos de construcción usados en las otras plantas\n')
# Out:
# Text(0.5, 1.0, 'Tipos de construcción usados en las otras plantas\n')

# %%
df_ground_floor_type
# Out:
# f    209619
# x     24877
# v     24593
# z      1004
# m       508
# Name: ground_floor_type, dtype: int64

# %%
df_floor_type = df_train_values_original[['ground_floor_type', 'other_floor_type', 'building_id']].merge(df_train_labels_original, on='building_id')
df_floor_type = df_floor_type.groupby(['ground_floor_type', 'other_floor_type', 'damage_grade']).count().reset_index()
df_floor_type['ground_other'] = df_floor_type[['ground_floor_type', 'other_floor_type']].apply(lambda x: ' - '.join(x), axis=1)
df_floor_type2 = df_floor_type[['ground_other', 'damage_grade', 'building_id']]
df_floor_type2.columns = ['Construccion en PB - otras plantas', 'Grado de daño', 'Cantidad']
df_floor_type2
#g_df_floor_type = df_floor_type[['ground_other', 'damage_grade_1', 'damage_grade_2', 'damage_grade_3']]
#g_df_floor_type
# Out:
#    Construccion en PB - otras plantas  Grado de daño  Cantidad
# 0                               f - j              1      3552
# 1                               f - j              2     13306
# 2                               f - j              3      8993
# 3                               f - q              1      6312
# 4                               f - q              2     86821
# 5                               f - q              3     54036
# 6                               f - s              1        84
# 7                               f - s              2       441
# 8                               f - s              3       139
# 9                               f - x              1      2526
# 10                              f - x              2     19309
# 11                              f - x              3     14100
# 12                              m - j              1        45
# 13                              m - j              2        76
# ...

# %%
#df_floor_type.columns = ['ground_floor_type', 'other_floor_type', 'damage_grade_1', 'damage_grade_2', 'damage_grade_3']
#df_floor_type['ground_other'] = df_floor_type[['ground_floor_type', 'other_floor_type']].apply(lambda x: ' - '.join(x), axis=1)
#g_df_floor_type = df_floor_type[['ground_other', 'damage_grade_1', 'damage_grade_2', 'damage_grade_3']]
##g_df_floor_type

# %%
fig,ax=plt.subplots(figsize=(20,15))

plt.grid(True)
g = sns.barplot(ax=ax,data=df_floor_type2,x='Construccion en PB - otras plantas',y='Cantidad',palette=['Gold', 'Orange', 'Tomato'],alpha=1,hue='Grado de daño')
g.set_title('Cantidad de edificios dañados segun tipo de daño y construccion en distintas plantas\n',size=35)
g.set_xlabel('Construccion en PB - otras plantas',size=25)
g.set_ylabel('Cantidad de edificios dañados',size=25)
fig.get_axes()[0].set_yscale('log')
g.legend(title='Grado de daño')

# %%
df_floor_type_1 = df_floor_type[['ground_floor_type', 'other_floor_type', 'damage_grade_1']].pivot(index='ground_floor_type', columns='other_floor_type')
df_floor_type_1
# Out:
#                   damage_grade_1
# other_floor_type               j     q     s     x
# ground_floor_type
# f                           3552  6312    84  2526
# m                             45    16    21     8
# v                           4403   394  4907   605
# x                            778   638   405   231
# z                            108    27     6    58

# %%
plt.figure(figsize=(12, 12))
ax = sns.heatmap(df_floor_type_1, cmap="mako", annot=True);
plt.title("Correlación entre columnas", size=30)
ax.tick_params(labelsize=15)
ax.tick_params(axis='x', rotation=90)
ax.tick_params(axis='y', rotation=0)

# %%
df_floor_type_2 = df_floor_type[['ground_floor_type', 'other_floor_type', 'damage_grade_2']].pivot(index='ground_floor_type', columns='other_floor_type')
df_floor_type_2
# Out:
#                   damage_grade_2
# other_floor_type               j      q     s      x
# ground_floor_type
# f                          13306  86821   441  19309
# m                             76    145    24     98
# v                           4637   2046  4798   1490
# x                           2173   9139   637   2587
# z                            170    169     4    189

# %%
plt.figure(figsize=(12, 12))
ax = sns.heatmap(df_floor_type_2, cmap="mako", annot=True);
plt.title("Correlación entre columnas", size=30)
ax.tick_params(labelsize=15)
ax.tick_params(axis='x', rotation=90)
ax.tick_params(axis='y', rotation=0)

# %%
df_floor_type_3 = df_floor_type[['ground_floor_type', 'other_floor_type', 'damage_grade_3']].pivot(index='ground_floor_type', columns='other_floor_type')
df_floor_type_3
# Out:
#                   damage_grade_3
# other_floor_type               j      q    s      x
# ground_floor_type
# f                           8993  54036  139  14100
# m                             16     37    5     17
# v                            281    331  443    258
# x                           1188   5132  112   1857
# z                            117     39    2    115

# %%
plt.figure(figsize=(12, 12))
ax = sns.heatmap(df_floor_type_3, cmap="mako", annot=True);
plt.title("Correlación entre columnas", size=30)
ax.tick_params(labelsize=15)
ax.tick_params(axis='x', rotation=90)
ax.tick_params(axis='y', rotation=0)

# %%
df_floor_type = df_train_values_original[['ground_floor_type', 'other_floor_type', 'building_id']]

# %%
df_train_values_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 40 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  uint8
#  2   geo_level_2_id                          260601 non-null  uint16
#  3   geo_level_3_id                          260601 non-null  uint16
#  4   count_floors_pre_eq                     260601 non-null  uint8
#  5   age                                     260601 non-null  uint16
#  6   area_percentage                         260601 non-null  uint16
#  7   height_percentage                       260601 non-null  uint16
#  8   land_surface_condition                  260601 non-null  category
#  9   foundation_type                         260601 non-null  category
# ...
